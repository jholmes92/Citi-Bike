# %% [markdown]
# # Exercise 2.2 | Task
#
# ##### 1. Import Libraries
# ##### 2. Create list of files in data folder
# ##### 3. Read, and join, the data sets
# ##### 4. Gathering weather data using NOAA API
# ##### 5. Merge weather data with NY CitiBike dataset

# %% [markdown]
# ##### 1. Import Libraries

# %%
import pandas as pd 
import numpy as np
import os 
import requests
import json
from datetime import datetime

# %% [markdown]
# ##### 2. Create list of files in data folder

# %%
# Create a list with all files in the folder using a list compehension

folderpath = r"C:\Users\repla\OneDrive\Documents\School\Data Visualizations with Python\Citi-Bike\NYCitiBike-Data"
filepaths = [os.path.join(folderpath, name) for name in os.listdir(folderpath)]

# %%
filepaths
# Out:
# ['C:\\Users\\repla\\OneDrive\\Documents\\School\\Data Visualizations with Python\\Citi-Bike\\NYCitiBike-Data\\2022-citibike-tripdata.zip',
#  'C:\\Users\\repla\\OneDrive\\Documents\\School\\Data Visualizations with Python\\Citi-Bike\\NYCitiBike-Data\\JC-202201-citibike-tripdata.csv.zip',
#  'C:\\Users\\repla\\OneDrive\\Documents\\School\\Data Visualizations with Python\\Citi-Bike\\NYCitiBike-Data\\JC-202202-citibike-tripdata.csv.zip',
#  'C:\\Users\\repla\\OneDrive\\Documents\\School\\Data Visualizations with Python\\Citi-Bike\\NYCitiBike-Data\\JC-202203-citibike-tripdata.csv.zip',
#  'C:\\Users\\repla\\OneDrive\\Documents\\School\\Data Visualizations with Python\\Citi-Bike\\NYCitiBike-Data\\JC-202204-citibike-tripdata.csv.zip',
#  'C:\\Users\\repla\\OneDrive\\Documents\\School\\Data Visualizations with Python\\Citi-Bike\\NYCitiBike-Data\\JC-202205-citibike-tripdata.csv.zip',
# ...

# %% [markdown]
# ##### 3. Read, and join, the data sets

# %%
# Read and concatenate all files simultaneously

df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Read and concatenate all files simultaneously
# ----> 3 df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index = True)
#
# File ~\anaconda3\envs\Citi-Bike\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\Citi-Bike\Lib\site-packages\pandas\core\reshape\concat.py:368, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
# ...

# %%
#we'll need to unpack the zip files in order to read the CSV's

# %%
import pandas as pd
import zipfile
import io

# %%
dfs = []
for filepath in filepaths:
    with zipfile.ZipFile(filepath) as z:
        for file_name in z.namelist():
            with z.open(file_name) as f:
                if file_name.endswith('.csv'):
                    dfs.append(pd.read_csv(io.BytesIO(f.read())))
# Out:
# C:\Users\repla\AppData\Local\Temp\ipykernel_31948\1121217755.py:7: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs.append(pd.read_csv(io.BytesIO(f.read())))
# C:\Users\repla\AppData\Local\Temp\ipykernel_31948\1121217755.py:7: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs.append(pd.read_csv(io.BytesIO(f.read())))
# C:\Users\repla\AppData\Local\Temp\ipykernel_31948\1121217755.py:7: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs.append(pd.read_csv(io.BytesIO(f.read())))
# C:\Users\repla\AppData\Local\Temp\ipykernel_31948\1121217755.py:7: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs.append(pd.read_csv(io.BytesIO(f.read())))
# ...

# %%
df = pd.concat(dfs, ignore_index=True)

# %%
df.shape
# Out:
# (30716683, 13)

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  2E89F1D88B8347E6   classic_bike  2022-04-08 19:50:00  2022-04-08 19:55:28
# 1  43F6D61DFEDAE4AF  electric_bike  2022-04-27 10:19:54  2022-04-27 10:33:29
# 2  21C7076071104314   classic_bike  2022-04-28 13:10:59  2022-04-28 13:17:18
# 3  7D7CEA2953427D0C   classic_bike  2022-04-13 20:21:18  2022-04-13 20:37:28
# 4  AD7E176748A4A55E  electric_bike  2022-04-29 18:56:24  2022-04-29 18:57:16
#
#          start_station_name start_station_id          end_station_name  \
# 0           E 89 St & 3 Ave          7265.10     Madison Ave & E 99 St
# 1        Broadway & W 29 St          6289.06        Broadway & W 29 St
# 2  E 123 St & Lexington Ave          7636.05  E 123 St & Lexington Ave
# 3           W 36 St & 9 Ave          6569.07           W 36 St & 9 Ave
# 4   Graham Ave & Withers St          5403.04   Graham Ave & Withers St
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual
# ...

# %%
df.tail()
# Out:
#                    ride_id  rideable_type           started_at  \
# 30716678  439B3B4ADB37F46F  electric_bike  2022-01-03 16:07:27
# 30716679  11C0F2F85CBF7623  electric_bike  2022-01-22 20:02:58
# 30716680  E77502BB6C6A7ADD   classic_bike  2022-01-26 12:35:21
# 30716681  75C57C18EE9980EA   classic_bike  2022-01-28 12:56:34
# 30716682  2EC5621EF3DCB2FA   classic_bike  2022-01-31 12:45:16
#
#                      ended_at   start_station_name start_station_id  \
# 30716678  2022-01-03 16:12:05  Leonard Gordon Park            JC080
# 30716679  2022-01-22 20:07:32  Leonard Gordon Park            JC080
# 30716680  2022-01-26 12:44:00  Leonard Gordon Park            JC080
# 30716681  2022-01-28 13:06:45  Leonard Gordon Park            JC080
# 30716682  2022-01-31 12:52:05  Leonard Gordon Park            JC080
#
#          end_station_name end_station_id  start_lat  start_lng   end_lat  \
# 30716678   Journal Square          JC103   40.74591 -74.057271  40.73367
# ...

# %%
# 4. This code iterates through each ZIP file, extracts all files, and checks if they end with .csv. If they do, it reads them into a DataFrame. This way, it handles multiple CSV files within each ZIP archive. Finally, it concatenates all DataFrames into a single one.

# %% [markdown]
# ##### 4. Gathering weather data using NOAA API

# %%
# Define your NOAA token  

Token = 'IqOutrQSSOGHVtbDODmfsFBVVyjHjque'

# %%
# Adjust the station ID, start date, and end date for LaGuardia Airport in 2022
station_id = 'GHCND:USW00014732'
start_date = '2022-01-01'
end_date = '2022-12-31'

# %%
# Get the API
r = requests.get(f'https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TAVG&limit=1000&stationid={station_id}&startdate={start_date}&enddate={end_date}', headers={'token': Token})

# %%
# Check if the request was successful
if r.status_code == 200:
    print("Data retrieved successfully.")
    # Process the data here
    data = r.json()
    # Check if 'results' key is present in the response
    if 'results' in data:
        if data['results']:
            print("First observation:", data['results'][0])
        else:
            print("No results found.")
    else:
        print("No results found in the response.")
else:
    print("Failed to retrieve data. Status code:", r.status_code)
# Out:
# Data retrieved successfully.
# First observation: {'date': '2022-01-01T00:00:00', 'datatype': 'TAVG', 'station': 'GHCND:USW00014732', 'attributes': 'H,,S,', 'value': 116}

# %%
data
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 365, 'limit': 1000}},
#  'results': [{'date': '2022-01-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 116},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 114},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 14},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': -27},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 32},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 49},
#   {'date': '2022-01-07T00:00:00',
# ...

# %%
# Create a DataFrame from the dictionary without modifying the original dataset
df1 = pd.DataFrame([data])

# %%
# Export the DataFrame to a CSV file titled 'ny_weather.csv'
df1.to_csv('ny_weather.csv', index=False)

# %% [markdown]
# ##### 5. Merge weather data with NY CitiBike dataset

# %%
d = data

# %%
d
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 365, 'limit': 1000}},
#  'results': [{'date': '2022-01-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 116},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 114},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 14},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': -27},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 32},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 49},
#   {'date': '2022-01-07T00:00:00',
# ...

# %%
# Secure all items in the response that correspond to TAVG

avg_temps = [item for item in d['results'] if item['datatype']=='TAVG']

# %%
# Get only the date field from all average temperature readings

dates_temp = [item['date'] for item in avg_temps]

# %%
# Get the temperature from all average temperature readings

temps = [item['value'] for item in avg_temps]

# %%
temps
# Out:
# [116,
#  114,
#  14,
#  -27,
#  32,
#  49,
#  7,
#  -25,
#  14,
#  16,
#  -54,
#  -19,
#  40,
#  48,
#  -67,
#  -80,
#  39,
#  18,
#  32,
#  51,
#  -60,
#  -59,
#  -7,
#  -2,
#  36,
#  -23,
#  -42,
#  1,
#  -48,
#  -71,
#  -34,
#  -17,
#  23,
#  64,
#  58,
#  -28,
#  -48,
#  5,
#  41,
#  28,
#  63,
#  86,
#  118,
#  28,
#  -43,
#  -47,
#  16,
#  116,
#  99,
#  1,
#  -26,
#  41,
#  56,
#  144,
#  11,
#  8,
#  -11,
#  24,
#  8,
#  26,
#  77,
#  56,
#  -19,
#  31,
#  96,
#  182,
#  87,
#  32,
#  40,
#  72,
#  51,
#  -23,
#  53,
#  116,
#  136,
#  82,
#  139,
#  131,
#  143,
#  104,
#  107,
#  72,
#  57,
#  96,
#  104,
#  59,
#  -15,
#  -12,
#  26,
#  99,
#  131,
#  72,
#  70,
#  76,
#  97,
#  86,
#  91,
#  128,
#  114,
#  86,
#  88,
#  134,
#  154,
#  163,
#  157,
#  157,
#  83,
#  79,
#  76,
#  94,
#  106,
#  146,
#  133,
#  128,
#  104,
#  115,
#  116,
#  82,
#  104,
#  129,
#  136,
#  121,
#  124,
#  120,
#  172,
#  148,
#  100,
#  104,
#  135,
#  154,
#  161,
#  171,
#  160,
# ...

# %%
# Put the results in a dataframe

df_temp = pd.DataFrame()

# %%
# Get only date and cast it to date time; convert temperature from tenths of Celsius to normal Celsius

df_temp['date'] = [datetime.strptime(d, "%Y-%m-%dT%H:%M:%S") for d in dates_temp]
df_temp['avgTemp'] = [float(v)/10.0 for v in temps]

# %%
df_temp.tail()
# Out:
#           date  avgTemp
# 360 2022-12-27     -0.7
# 361 2022-12-28      3.4
# 362 2022-12-29      6.4
# 363 2022-12-30      9.3
# 364 2022-12-31      8.2

# %%
df_temp.head()
# Out:
#         date  avgTemp
# 0 2022-01-01     11.6
# 1 2022-01-02     11.4
# 2 2022-01-03      1.4
# 3 2022-01-04     -2.7
# 4 2022-01-05      3.2

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
df['started_at'] = pd.to_datetime(df['started_at'], dayfirst = True)

# %%
df['date'] = pd.to_datetime(df['started_at'], format='%Y-%m-%d').dt.date

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df_temp.head()
# Out:
#         date  avgTemp
# 0 2022-01-01     11.6
# 1 2022-01-02     11.4
# 2 2022-01-03      1.4
# 3 2022-01-04     -2.7
# 4 2022-01-05      3.2

# %%
# %%time
df_merged = df.merge(df_temp, how = 'left', on = 'date', indicator = True)
# Out:
# CPU times: total: 24.5 s
# Wall time: 4min 1s

# %%
df_merged.head()
# Out:
#             ride_id  rideable_type          started_at             ended_at  \
# 0  2E89F1D88B8347E6   classic_bike 2022-04-08 19:50:00  2022-04-08 19:55:28
# 1  43F6D61DFEDAE4AF  electric_bike 2022-04-27 10:19:54  2022-04-27 10:33:29
# 2  21C7076071104314   classic_bike 2022-04-28 13:10:59  2022-04-28 13:17:18
# 3  7D7CEA2953427D0C   classic_bike 2022-04-13 20:21:18  2022-04-13 20:37:28
# 4  AD7E176748A4A55E  electric_bike 2022-04-29 18:56:24  2022-04-29 18:57:16
#
#          start_station_name start_station_id          end_station_name  \
# 0           E 89 St & 3 Ave          7265.10     Madison Ave & E 99 St
# 1        Broadway & W 29 St          6289.06        Broadway & W 29 St
# 2  E 123 St & Lexington Ave          7636.05  E 123 St & Lexington Ave
# 3           W 36 St & 9 Ave          6569.07           W 36 St & 9 Ave
# 4   Graham Ave & Withers St          5403.04   Graham Ave & Withers St
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual  \
# ...

# %%
df_merged['_merge'].value_counts(dropna = False)
# Out:
# both          30716683
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_merged.to_csv('newyork_data.csv')

# %%
df.shape
# Out:
# (30716683, 14)
